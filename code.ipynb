# %%
# bài 1:
a=int(input("Nhập số a: "))
print("gấp đôi a là:",a*2)
# Out:
# gấp đôi a là: 4000

# %%
#bài 2:
a,b=map(float,input("Nhập chiều rộng và dài:").split())
print("diện tích cần tìm là:",a*b-3.14*(a/2)**2)
# Out:
# diện tích cần tìm là: 2.86

# %%
# bài 3:
a= input()
if a.isupper():
    print(a.lower())
else:
    print(a.upper())
# Out:
# s

# %%
#bài 4:
a=input()
if a.isalpha():
    print(a, "là kí tự alphabet")
else:
    print(a, "không phải là kí tự alphabet")
# Out:
# a là kí tự alphabet

# %%
#Bài 5:
a=input()
if a=='A':
    print("không có chữ cái đứng trước 'a'")
else:
    print("chữ cái đứng trước là:",chr(ord(a.lower())-1))
# Out:
# chữ cái đứng trước là: m

# %%
# Bài 6:
a,b,c=map(int,input().split())
if a+b<=c or a+c<=b or b+c<=a:
    print("không phải là 3 cạnh của tam giác")
else:
    p=(a+b+c)/2
    print("diện tích tam giác là:",(p*(p-a)*(p-b)*(p-c))**0.5)
# Out:
# không phải là 3 cạnh của tam giác

# %%
# bài 7:
a=input()
print(a[4],a[8])
# Out:
# i v

# %%
# Bai 8:
name=input("Ten chu ho:")
a=int(input("Chi so thang truoc:"))
b=int(input("Chi so thang nay:"))
c=b-a
print("Ho va ten:",name)
if 0<c<=50:
    print("So tien phai tra:",round(c*1984*1.08))
elif 50<c<=100:
    print("So tien phai tra:",round(50*1984*1.08+(c-50)*2050*1.08))
elif 100<c<=200:
    print("So tien phai tra:",round(50*1984*1.08+50*2050*1.08+(c-100)*2380*1.08))
elif 200<c<=300:
    print("So tien phai tra:",round(50*1984*1.08+50*2050*1.08+100*2380*1.08+(c-200)*2998*1.08))   
elif 300<c<=400:
    print("So tien phai tra:",round(50*1984*1.08+50*2050*1.08+100*2380*1.08+100*2998*1.08+(c-300)*3350*1.08))
else:
    print("So tien phai tra:",round(50*1984*1.08+50*2050*1.08+100*2380*1.08+100*2998*1.08+100*3350*1.08+(c-400)*3460*1.08))
# Out:
# Ho va ten: lkj
# So tien phai tra: 107136

# %%
# 1:
a=int(input())
if a%2==0:
    print(a, "là số chẵn")
else:
    print(a, "là số lẻ")
# Out:
# 56 là số chẵn

# %%
# 2:
a=int(input())
b=str(a)
if b[-1]== "5":
    print("True")
else:
    print("False")
# Out:
# True

# %%
#3:
a=int(input())
if a%15==0:
    print("True")
else:
    print("False")
# Out:
# True

# %%
#4:
a=int(input())
if 2026-a>=18:
    print("Đủ tuổi đi bầu cử")
else:
    print("Không đủ tuổi đi bầu cử")
# Out:
# Đủ tuổi đi bầu cử

# %%
#5:
a,b=map(int,input().split())
if a>b:
    print(a)
elif a<b:
    print(b)
else:    
    print("a và b bằng nhau")
# Out:
# a và b bằng nhau

# %%
#6:
a=input()
if a.isalpha():
    print(a, "là chữ cái")
elif a.isdigit():
    print(a, "là số")
else:
    print(a, "là ký tự đặc biệt")

# %%
#7:
a=float(input())
if 8<=a<=10:
    print("Giỏi")
elif 6.5<=a<8:
    print("Khá")
elif 5<=a<6.5:
    print("Trung bình")     
else:
    print("Yếu")
# Out:
# Yếu

# %%
#8:
a=int(input())
if a%400==0 or (a%4==0 and a%100!=0):
    print("Nhuận")
else:
    print("Không nhuận")
# Out:
# Nhuận

# %%
#9:
n = int(input("Nhập số từ 0 đến 9: "))

match n:
    case 0:
        print("Không")
    case 1:
        print("Một")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bốn")
    case 5:
        print("Năm")
    case 6:
        print("Sáu")
    case 7:
        print("Bảy")
    case 8:
        print("Tám")
    case 9:
        print("Chín")
    case _:
        print("Số không hợp lệ")

# %%
#10:
a=float(input())
if a>=4:
    print("Qua môn")
else:
    print("Học lại")
# Out:
# Qua môn

# %%
#11:
a=int(input())
if 2025-a>=18:
    print("Đủ 18 tuổi")
else:
    print("Không đủ 18 tuổi")
# Out:
# Đủ 18 tuổi
